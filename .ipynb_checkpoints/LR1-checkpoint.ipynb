# %%
import pandas as pd

dataframe = pd.read_csv('titanic.csv')
dataframe.head()
print(dataframe.shape)
print(dataframe.columns)


# dataframe[dataframe['Sex'] == 'female'].head(5)[['Name','Sex','Age']]
print("1.Кількість жінок і чоловіків на борту:")
a = dataframe[dataframe['Sex'] == 'female']['PassengerId'].count()
b = dataframe['PassengerId'].count() - a
print(a, b)
# Out:
# (891, 12)
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')
# 1.Кількість жінок і чоловіків на борту:
# 314 577
